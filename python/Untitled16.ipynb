# %%
def prime_v1(i):
    if i==0 or i==1:
        return False
    for d in range(2,i):
        if i % d == 0:
            return False
    else:
        return 
#x=[2,3]
a=int(input("Enter the upper limit "))
b=int(input("Enter the lower limit "))
for j in range(a,b):
    tex=prime_v1(j)
    if tex == True:
        print(j,"TRUE")
        #x.append(j)
    else:
        continue
# Out:
# Enter the upper limit 1
# Enter the lower limit 21

# %%
def prime_v1(i):
    if i==0 or i==1:
        return 0
    for d in range(2,i):
        if i % d == 0:
            return 0
    else:
        return 1
x=[2,3]
a=int(input("Enter the upper limit "))
b=int(input("Enter the lower limit "))
print("List of prime no.")
for j in range(a,b):
    tex = prime_v1(j)
    if tex == 1:
        print(j)
        x.append(j)
    else:
        continue
print("\nLargest prime no. among the given boundary = ",max(x))
# Out:
# Enter the upper limit 1
# Enter the lower limit 2
# List of prime no.
#
# Largest prime no. among the given boundary =  3
